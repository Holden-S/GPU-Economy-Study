# %% [markdown]
# **Now that I have accessed and sorted my data through Google Cloud's BigQuery, I will be using python to create visualizations for the data. Such as plots, numeric statistics, and other values.**

# %%
import pandas as pd
GPU_Data = pd.read_csv('GPU_Benchmarks_Specs.csv')
GPU_Data
# Out:
#                           gpuName  G3Dmark  G2Dmark    price  gpuValue    TDP  \
# 0               Radeon RX Vega 64    14636      810   799.99     18.30  295.0
# 1    Radeon Vega Frontier Edition    13748      753  1679.99      8.18  350.0
# 2                  Radeon Pro Duo     8324      715  1199.06      6.94  350.0
# 3                    Radeon X1550       67      253   155.00      0.43   27.0
# 4                    Radeon X1550       67      253   155.00      0.43   27.0
# ..                            ...      ...      ...      ...       ...    ...
# 187             Radeon RX Vega 56    13636      784   752.99     18.11  210.0
# 188           GeForce GTX TITAN Z     9189      648  1515.00      6.07  375.0
# 189            GeForce GTX 780 Ti     9312      626   339.99     27.39  250.0
# 190                Radeon RX 6800    20667     1030   758.99     27.23  250.0
# 191                    Radeon VII    16767      788  1899.95      8.82  300.0
#
#      powerPerformance  testDate category manufacturer  ... memClock  \
# 0               49.62      2017  Desktop          AMD  ...      945
# 1               39.28      2017  Desktop          AMD  ...      945
# 2               23.78      2016  Desktop          AMD  ...      500
# 3                2.47      2009  Desktop          ATI  ...      333
# 4                2.47      2009  Desktop          ATI  ...      400
# ..                ...       ...      ...          ...  ...      ...
# 187             64.93      2017  Desktop          AMD  ...      800
# 188             24.50      2014  Desktop       NVIDIA  ...     1750
# 189             37.25      2013  Desktop       NVIDIA  ...     1753
# 190             82.67      2020  Desktop          AMD  ...     2000
# 191             55.89      2019  Desktop          AMD  ...     1000
#
#      unifiedShader  tmu  rop  pixelShader  vertexShader    igp           bus  \
# 0           4096.0  256   64          NaN           NaN  False  PCIe 3.0 x16
# 1           4096.0  256   64          NaN           NaN  False  PCIe 3.0 x16
# 2           4096.0  256   64          NaN           NaN  False  PCIe 3.0 x16
# 3              NaN    4    4          4.0           2.0  False  PCIe 1.0 x16
# 4              NaN    4    4          4.0           2.0  False  PCIe 1.0 x16
# ..             ...  ...  ...          ...           ...    ...           ...
# 187         3584.0  224   64          NaN           NaN  False  PCIe 3.0 x16
# 188         2880.0  240   48          NaN           NaN  False  PCIe 3.0 x16
# 189         2880.0  240   48          NaN           NaN  False  PCIe 3.0 x16
# 190         3840.0  240   96          NaN           NaN  False  PCIe 4.0 x16
# 191         3840.0  240   64          NaN           NaN  False  PCIe 3.0 x16
#
#      memType    gpuChip
# 0       HBM2    Vega 10
# 1       HBM2    Vega 10
# 2        HBM  Capsaicin
# 3       DDR2      RV505
# 4       DDR2      RV515
# ..       ...        ...
# 187     HBM2    Vega 10
# 188    GDDR5     GK110B
# 189    GDDR5     GK110B
# 190    GDDR6    Navi 21
# 191     HBM2    Vega 20
#
# [192 rows x 25 columns]

# %%
GPU_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gpuName           192 non-null    object
#  1   G3Dmark           192 non-null    int64
#  2   G2Dmark           192 non-null    int64
#  3   price             192 non-null    float64
#  4   gpuValue          192 non-null    float64
#  5   TDP               192 non-null    float64
#  6   powerPerformance  192 non-null    float64
#  7   testDate          192 non-null    int64
#  8   category          192 non-null    object
#  9   manufacturer      192 non-null    object
#  10  productName       192 non-null    object
#  11  releaseYear       192 non-null    int64
#  12  memSize           192 non-null    float64
#  13  memBusWidth       192 non-null    int64
#  14  gpuClock          192 non-null    int64
#  15  memClock          192 non-null    int64
#  16  unifiedShader     188 non-null    float64
#  17  tmu               192 non-null    int64
#  18  rop               192 non-null    int64
#  19  pixelShader       4 non-null      float64
#  20  vertexShader      4 non-null      float64
#  21  igp               192 non-null    bool
#  22  bus               192 non-null    object
#  23  memType           192 non-null    object
#  24  gpuChip           192 non-null    object
# dtypes: bool(1), float64(8), int64(9), object(7)
# memory usage: 36.3+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
dataset = GPU_Data
dataframe = pd.DataFrame(data=dataset, columns=('G3Dmark','G2Dmark','memSize','memBusWidth','gpuClock','memClock','unifiedShader','tmu','rop'))
dataframe["G3Dmark"] = dataset.G3Dmark
matrix = dataframe.corr()

# plotting correlation matrix
sns.heatmap(matrix, cmap="Blues", annot=True)
# Out:
# <Axes: >
